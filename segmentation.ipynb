# %%
! git clone https://github.com/anisharoy/handwriting_VAE.git
# Out:
# fatal: destination path 'handwriting_VAE' already exists and is not an empty directory.

# %%
! git clone https://github.com/anisharoy/handwriting_output.git
# Out:
# Cloning into 'handwriting_output'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 12 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (12/12), done.

# %%
import cv2
import numpy as np
import glob2




#files = glob2.glob("F://AR//python//handwriting//Writings//c.jpg")
files = glob2.glob("handwriting_VAE/Writings/c.jpg")
print(files)
for filename in files:
    # Load the image
    image = cv2.imread(filename)
    print(image.shape)
    
    #cv2.imshow('orig',image)
    #cv2.waitKey(0)
    
    #grayscale
    gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    #cv2.imshow('gray',gray)
    #cv2.waitKey(0)
    
    #binary
    ret,thresh = cv2.threshold(gray,127,255,cv2.THRESH_BINARY_INV)
    #cv2.imshow('second',thresh)
    #cv2.waitKey(0)
    
    #dilation
    kernel = np.ones((5,150), np.uint8)
    img_dilation = cv2.dilate(thresh, kernel, iterations=1)
    #cv2.imshow('dilated',img_dilation)
    #cv2.waitKey(0)
    
    #find contours
    im2,ctrs, hier = cv2.findContours(img_dilation.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    #sort contours
    sorted_ctrs = sorted(ctrs, key=lambda ctr: cv2.boundingRect(ctr)[0])
    
    for i, ctr in enumerate(sorted_ctrs):
        # Get bounding box
        x, y, w, h = cv2.boundingRect(ctr)
    
        # Getting ROI
        roi = gray[y:y+h, x:x+w]
        
        cv2.imwrite("handwriting_output/handwriting_output/line/line"+str(i)+".png",roi)
        print("writing")
        '''# show ROI
#         cv2.imshow('segment no:'+str(i),roi)
#         cv2.rectangle(image,(x,y),( x + w, y + h ),(90,0,255),2)
#         cv2.waitKey(500)
    
#     #cv2.WINDOW_NORMAL makes the output window resizealbe
#     cv2.namedWindow('marked areas', cv2.WINDOW_NORMAL)
#     #resize the window according to the screen resolution
#     cv2.resizeWindow('marked areas', 1920, 1080)
#     cv2.imshow('marked areas',image)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()'''
# Out:
# ['handwriting_VAE/Writings/c.jpg']
# (2504, 3000, 3)
# writing
# writing
# writing
# writing
# writing
# writing
# writing
# writing
# writing
# writing
# writing

# %%
import cv2
import numpy as np
import glob2


files = glob2.glob("handwriting_output/handwriting_output/line/*.png")

for filename in files:
    # Load the image
    image = cv2.imread(filename)
    
    #cv2.imshow('orig',image)
    #cv2.waitKey(0)
    
    #grayscale
    gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    # cv2.imshow('gray',gray)
    # cv2.waitKey(0)
    
    #binary
    ret,thresh = cv2.threshold(gray,127,255,cv2.THRESH_BINARY_INV)
    # cv2.imshow('second',thresh)
    # cv2.waitKey(0)
    
    #dilation
    kernel = np.ones((5,35), np.uint8)
    img_dilation = cv2.dilate(thresh, kernel, iterations=1)
    # cv2.imshow('dilated',img_dilation)
    # cv2.waitKey(0)
    
    #find contours
    im2,ctrs, hier = cv2.findContours(img_dilation.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    #sort contours
    sorted_ctrs = sorted(ctrs, key=lambda ctr: cv2.boundingRect(ctr)[0])
    
    for i, ctr in enumerate(sorted_ctrs):
        # Get bounding box
        x, y, w, h = cv2.boundingRect(ctr)
    
        # Getting ROI
        roi = image[y:y+h, x:x+w]
        print("writing handwriting_output/handwriting_output/word/word"+str(files.index(filename))+str(i)+".png")
        cv2.imwrite("handwriting_output/handwriting_output/word/word"+str(files.index(filename))+str(i)+".png",roi)
        # show ROI
#         cv2.imshow('segment no:'+str(i),roi)
#         cv2.rectangle(image,(x,y),( x + w, y + h ),(90,0,255),2)
#         cv2.waitKey(500)
    
#     #cv2.WINDOW_NORMAL makes the output window resizealbe
#     cv2.namedWindow('marked areas', cv2.WINDOW_NORMAL)
#     #resize the window according to the screen resolution
#     cv2.resizeWindow('marked areas', 1920, 1080)
#     cv2.imshow('marked areas',image)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()
# Out:
# writing handwriting_output/handwriting_output/word/word00.png
# writing handwriting_output/handwriting_output/word/word01.png
# writing handwriting_output/handwriting_output/word/word02.png
# writing handwriting_output/handwriting_output/word/word03.png
# writing handwriting_output/handwriting_output/word/word04.png
# writing handwriting_output/handwriting_output/word/word05.png
# writing handwriting_output/handwriting_output/word/word06.png
# writing handwriting_output/handwriting_output/word/word07.png
# writing handwriting_output/handwriting_output/word/word08.png
# writing handwriting_output/handwriting_output/word/word09.png
# writing handwriting_output/handwriting_output/word/word010.png
# writing handwriting_output/handwriting_output/word/word011.png
# writing handwriting_output/handwriting_output/word/word10.png
# writing handwriting_output/handwriting_output/word/word20.png
# writing handwriting_output/handwriting_output/word/word21.png
# ...

# %%
import cv2
import numpy as np
import glob2


files = glob2.glob("handwriting_output/handwriting_output/word/*.png")

for filename in files:
    # Load the image
    image = cv2.imread(filename)
    #print(image)
#     cv2.imshow('orig',image)
#     cv2.waitKey(0)
    
    #Resize the contour containing the word using the code as follows.
    image = cv2.resize(image,None,fx=4, fy=4, interpolation = cv2.INTER_CUBIC)
#     cv2.imshow('rez',image)
#     cv2.waitKey(0)
     
    #grayscale
    gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    # cv2.imshow('gray',gray)
    # cv2.waitKey(0)
    
    #binary
    ret,thresh = cv2.threshold(gray,127,255,cv2.THRESH_BINARY_INV)
    # cv2.imshow('second',thresh)
    # cv2.waitKey(0)
    
    #dilation
    kernel = np.ones((5,5), np.uint8)
    img_dilation = cv2.dilate(thresh, kernel, iterations=1)
    # cv2.imshow('dilated',img_dilation)
    # cv2.waitKey(0)
    
    #find contours
    im2,ctrs, hier = cv2.findContours(img_dilation.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    #sort contours
    sorted_ctrs = sorted(ctrs, key=lambda ctr: cv2.boundingRect(ctr)[0])
    
    for i, ctr in enumerate(sorted_ctrs):
        # Get bounding box
        x, y, w, h = cv2.boundingRect(ctr)
    
        # Getting ROI
        roi = image[y:y+h, x:x+w]
        print("writing handwriting_output/handwriting_output/char/char"+str(files.index(filename))+str(i)+".png")
        cv2.imwrite("handwriting_output/handwriting_output/char/char"+str(files.index(filename))+str(i)+".png",roi)
        # show ROI
#         cv2.imshow('segment no:'+str(i),roi)
#         cv2.rectangle(image,(x,y),( x + w, y + h ),(90,0,255),2)
#         cv2.waitKey(500)
    
#     #cv2.WINDOW_NORMAL makes the output window resizealbe
#     cv2.namedWindow('marked areas', cv2.WINDOW_NORMAL)
#     #resize the window according to the screen resolution
#     cv2.resizeWindow('marked areas', 1920, 1080)
#     cv2.imshow('marked areas',image)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()
# Out:
# writing handwriting_output/handwriting_output/char/char00.png
# writing handwriting_output/handwriting_output/char/char01.png
# writing handwriting_output/handwriting_output/char/char02.png
# writing handwriting_output/handwriting_output/char/char03.png
# writing handwriting_output/handwriting_output/char/char04.png
# writing handwriting_output/handwriting_output/char/char05.png
# writing handwriting_output/handwriting_output/char/char06.png
# writing handwriting_output/handwriting_output/char/char07.png
# writing handwriting_output/handwriting_output/char/char08.png
# writing handwriting_output/handwriting_output/char/char09.png
# writing handwriting_output/handwriting_output/char/char010.png
# writing handwriting_output/handwriting_output/char/char10.png
# writing handwriting_output/handwriting_output/char/char20.png
# writing handwriting_output/handwriting_output/char/char21.png
# writing handwriting_output/handwriting_output/char/char22.png
# ...
